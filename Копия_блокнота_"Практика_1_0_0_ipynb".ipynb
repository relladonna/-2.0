# %% [markdown]
# <a href="https://colab.research.google.com/github/relladonna/-2.0/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0_1_0_0_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
# # Выбран кодовый формат
# ```
#
# ФИО: Мосина Вероника Григорьевна

# %% [markdown]
# # Задание (совместное с преподавателем)

# %% [markdown]
# Напишите систему для учёта отпусков с возможностью узнавать, сколько дней отпуска осталось у того или иного сотрудника.
# Для этого создайте класс Employee со следующими методами:
#
# - Метод consume_vacation должен отвечать за списание дней отпуска.
#
# Единственный параметр этого метода (кроме self) — количество потраченных отпускных дней (целое число).
#
# При вызове метода consume_vacation соответствующее количество дней должно вычитаться из общего числа доступных отпускных дней сотрудника.
#
# Чтобы определить число доступных отпускных дней конкретного сотрудника, в классе опишите атрибут экземпляра |, который по умолчанию будет равен значению атрибута класса vacation_days, и используйте этот атрибут в работе метода.
#
# - Метод get_vacation_details должен возвращать остаток отпускных дней сотрудника в формате: ```Остаток отпускных дней: <число>.```
#
#
# Чтобы проверить работу программы:
# 1. Создайте экземпляр класса Employee.
# 2. Вызовите метод consume_vacation, указав подходящее значение аргумента, например 7.
# 3. Вызовите метод get_vacation_details.

# %%
class Employee:
  vacation_days = 28
  def __init__(self, first_name, second_name, gender):
    self.first_name = first_name
    self.second_name = second_name
    self.gender = gender
    self.remaining_vacation_days = self.vacation_days #количество доступных отпускных дней

  def consume_vacation(self, days):
    self.remaining_vacation_days -= days

  def get_vacation_details(self):
    return f'Остаток отпускных дней: {self.remaining_vacation_days}'


employee = Employee('Олег', "СуперОлег", "м")
employee2 = Employee('Олег', "НеСуперОлег", "м")

print(f'\nИмя:',employee.first_name,
      f'\nФамилия:',employee.second_name,
      f'\nПол:',employee.gender,
      f'\nКоличество доступных дней:',employee.remaining_vacation_days,'\n')

print('-'*20)

print(f'\nИмя:',employee2.first_name,
      f'\nФамилия:',employee2.second_name,
      f'\nПол:',employee2.gender,
      f'\nКоличество доступных дней:',employee2.remaining_vacation_days,'\n')

print(f'В отпуск уехал {employee.first_name} в Майами {14} дней')
employee.consume_vacation(14) # Олег в отпуске

print(employee.get_vacation_details())

print(f'\nИмя:',employee2.first_name,
      f'\nФамилия:',employee2.second_name,
      f'\nПол:',employee2.gender,
      f'\nКоличество доступных дней:',employee2.remaining_vacation_days,'\n')
# Out:
# Имя: Олег
# Фамилия: СуперОлег
# Пол: м
# Количество доступных дней: 28
#
# --------------------
#
# Имя: Олег
# Фамилия: НеСуперОлег
# Пол: м
# Количество доступных дней: 28
#
# В отпуск уехал Олег в Майами 14 дней
# Остаток отпускных дней: 14
#
# Имя: Олег
# Фамилия: НеСуперОлег
# Пол: м
# Количество доступных дней: 28

# %% [markdown]
# # Задание 1

# %% [markdown]
# Задание:
#
# Создайте класс с именем Rectangle который имеет:
# - Атрибуты ширины и высоты.
# - Метод расчета площади.
# - Метод расчета периметра.
# - Метод отображения размеров прямоугольника.
#
# Создайте экземпляр класса Rectangleи продемонстрируйте его функциональность.

# %%
class Rectangle:
  def __init__(self, width, height):
    self.width = width
    self.height = height

  def square(self):
    sq = self.width*self.height
    return sq

  def perimetr(self):
    per = (self.width + self.height)*2
    return per

  def sizes(self):
    print(f'\nШирина:',self.width,
          f'\nВысота:',self.height,'\n')

rectangle = Rectangle(5, 10)

rectangle.sizes()
print(f'\nПлощадь прямоугольника:', rectangle.square(),
      f'\nПериметр прямоугольника:',rectangle.perimetr(),'\n')
# Out:
# Ширина: 5
# Высота: 10
#
#
# Площадь прямоугольника: 50
# Периметр прямоугольника: 30

# %% [markdown]
# # Задание 2

# %% [markdown]
# Задание: Создайте мини версию банковской системы:
#
#
# Инструкции:
#
# 1. Создайте класс BankAccountсо следующими атрибутами:
#     - account_holder -  владелец счета
#     - balance - баланс счета
#
# 2. Реализуйте следующие методы:
#     - Метод для инициализации владельца счета: имя владельца счета и установите начальный баланс на 0.
#     - deposit(amount): Добавьте указанную сумму к балансу.
#     - withdraw(amount): Вычесть указанную сумму из баланса, если средств достаточно; в противном случае вывести предупреждение.
#     - get_balance(): Возврат текущего баланса.
#
#
# Создайте объект класса и продемонстрируйте его возможности

# %%
class BankAccountсо:
  balance = 0

  def __init__(self, account_holder):
    self.account_holder = account_holder

  def get_data(self):
    print(f'\nВладелец счета:', self.account_holder,
          f'\nБаланс:', self.balance,'\n')

  def deposit(self, amount):
    self.balance += amount
    return self.balance

  def withdraw(self, amount):
    if self.balance >= amount:
      self.balance -= amount
      return self.balance
    else:
      print('На вашем счету недостаточно средств')

  def get_balance(self):
    print(f'На вашем счету: {self.balance}')


account = BankAccountсо('Олег')
account.get_data()
account.deposit(8000)
account.get_data()
account.withdraw(3000)
account.get_data()
account.withdraw(9000)
# Out:
# Владелец счета: Олег
# Баланс: 0
#
#
# Владелец счета: Олег
# Баланс: 8000
#
#
# Владелец счета: Олег
# Баланс: 5000
#
# На вашем счету недостаточно средств

# %% [markdown]
# # Задание 3

# %% [markdown]
# Возьмите код и задание (Рыцарь и дракон) из предыдущей практики и реализуйте его с применением классов

# %%
import random


class Character:
  def __init__(self, name):
    self.name = name

  armor = 30000
  hp = 13000
  critical_damage = 5000

  def attack_character(self):
    damage = random.randint(100, self.critical_damage)
    return damage

  def take_damage(self, dragon_damage):
    if self.armor < dragon_damage:
      self.hp = self.hp - dragon_damage + self.armor
      return self.hp
    else:
      return self.hp

  def evasion(self):
    print('Рыцарь избежал атаки.')
    return self.hp

class Dragon:
  name = 'Двалин'
  hp = 30000
  critical_damage = 6000

  def attack_dragon(self):
    damage = random.randint(500, self.critical_damage)
    return damage

  def take_damage(self, character_damage):
    if self.hp < character_damage:
      self.hp = 0
      print('Рыцарь победил! Сразил дракона.')
      return self.hp
    else:
      self.hp -= character_damage
      return self.hp

  def evasion(self, character_damage):
    print('Дракон уклонился.')
    return self.hp

  def inaction(self):
    print('Дракон ожидает удар')


def fight(character, dragon):
  action_dragon1 = ['evasion', 'take_damage']
  action_dragon2 = ['attack_dragon', 'inaction']
  while character.hp > 0 and dragon.hp > 0:
    print('\nВыберите действие:\n \
    1. Атака\n \
    2. Уклон')
    action = int(input())
    if action == 1:
      character_damage = character.attack_character()
      dragon_damage = dragon.attack_dragon(dragon)
      if random.choice(action_dragon1) == 'evasion':
        print(f'Дракон уклонился от удара в {character_damage}, HP дракона всё так же: {dragon.hp}')
      else:
        if random.choice(action_dragon2) == 'attack_dragon':
          dr_take = dragon.take_damage(dragon, character_damage)
          ch_take = character.take_damage(dragon_damage)
          print(f'\nРыцарь делает свой удар: {character_damage}',
          f'\nТеперь здоровье дракона: {dr_take}')
          print(f'\nНо что же это! Рыцарь {character.name} не заметил молниеностный удар дракона!',
          f'\nДвалин наносит: {dragon_damage}')
          if dragon_damage <= character.armor:
            print('Удар не прошёл')
          print(f'Здоровье рыцаря: {ch_take}')
        else:
          print(f'\nРыцарь делает свой удар: {character_damage}\n \
          Теперь здоровье дракона: {dragon.take_damage(dragon, character_damage)}')

    elif action == 2:
      if random.choice(action_dragon1) == 'evasion':
        print('Хм? Вы оба отпрыгнули. Никто не решается на удар?')
      else:
        print(f'{character.name} уклонился от удара дракона: {dragon_damage}')
    else:
      ch_take = character.take_damage(dragon_damage)
      print(f'{character.name} замешкался! Дракон сделал свой ход!')
      print(f'\nДвалин наносит: {dragon_damage}')
      if dragon_damage <= character.armor:
        print('Удар не прошёл')
      print(f'Здоровье рыцаря: {ch_take}')

def final_history(ch_hp, dr_hp):
  if ch_hp == 0:
    print('--------------\n \
    В ярости схватки небеса покрылись черными облаками, как будто мир сам оплакивал судьбу храбреца.\n \
    Рыцарь, облеченный в сверкающие доспехи, достойно сражался против громадного дракона, чьи огненные когти оставляли глубокие трещины на земле.\n \
    Каждый удар меча отзывался громом в сердце битвы, но с каждым мгновением стало понятно, что силы были неравны.\n \
    \n \
    Светлые глаза рыцаря не уставали смотреть в бездну, из которой извергался адский огонь, и в его груди горел неугасимый дух воина.\n \
    В последний раз он поднял меч к небесам, призывая всю свою силу и веру в победу.\n \
    В этот момент он вспомнил облик своей любимой, о том, ради кого он сражается, и слезы наворачивались на его глаза.\n \
    \n \
    Но дракон, почувствовав, что соперник истощается, внезапно нанес мощный удар своим хвостом, сбив рыцаря с ног.\n \
    В этот миг казалось, что время остановилось. Он встретился взглядом с ужасом, и в ту секунду все его мечты о мире и мирной жизни разбились, как хрустальный сосуд.\n \
    \n \
    Рыцарь поднялся в последний раз, несмотря на раны. Он шагнул вперед, его сердце билось в ритме готовящегося финального удара.\n \
    Но дракон, с невероятной скоростью, обрушил на него поток огненного дыхания.\n \
    Яркий, ослепляющий свет охватил поле битвы, и в этот миг рыцарь осознал: иногда даже самые смелые сердца не могут победить тьму.\n \
    \n \
    Когда огонь утих, мир замер в глубоком молчании. Сотни людей, собравшихся на поле битвы, стояли в скорбном ожидании.\n \
    На земле остались лишь обломки доспехов, отражающие солнечные лучи, как напоминание о подвиге, о рыцаре, который отдал свою жизнь ради надежды на будущее.\n \
    \n \
    Так закончилась великая битва. Легенда о рыцаре, который смог бы сразиться с драконом,\n \
    но не смог выстоять против его ярости, осталась в сердцах людей, как история о мужестве, жертве и неизбежности судьбы.')
  else:
    print('--------------\n \
    Рыцарь, закутанный в сверкающие доспехи, стоял на вершине холма, устремив взгляд на поверженного дракона.\n \
    Огненная сущность, некогда внушающая страх, теперь лежала бездыханной, светлая чешуя мерцала на фоне заката.\n \
    Его меч, раскалённый в битве, медленно опустился, когда он, наконец, осознал, что страшная угроза позади.\n \
    \n \
    Собравшись с силами, он направился к странному призыву, доносившемуся из крепости, которую он так долго штурмовал.\n \
    Пройдя через развалины, он нашёл замок, окутанный полумраком. И вот, в самой глубине, в клетке из железных прутьев, в слезах и страхе находилась принцесса.\n \
    Её глаза, полные надежды, встретились с его взглядом.\n \
    \n \
    — Всё в порядке, моя принцесса, — произнёс рыцарь, расправляя плечи и смахивая капли пота с лба. — Я пришёл за тобой.\n \
    \n \
    Скрипнув дверями, он освободил её от оков. Принцесса, наконец, почувствовав себя в безопасности, бросилась в его объятия.\n \
    Они стояли так некоторое время, слыша только звуки природы вокруг, словно мир вокруг них воскрес.\n \
    \n \
    — Ты настоящий герой, — прошептала она, взглянув ему в лицо с благодарностью. — Как мне тебя вознаградить?\n \
    \n \
    — Достаточно знать, что ты в безопасности, — ответил рыцарь, улыбаясь. — Мы можем вернуться домой.\n \
    \n \
    Уже за пределами крепости, они направились к горизонту, где солнце садилось, окрашивая небо в непередаваемые цвета.\n \
    Вместе, с надеждой в сердцах, они начали новый путь, зная, что впереди их ждет мир, в котором они снова смогут быть счастливыми.\n \
    \n \
    И в этот момент они поняли, что настоящая победа — это не только сокрушение врага, но и возможность жить, любить и защищать друг друга.')

def beginning(name):
  print('---------------\n \
  Рыцарь, облачённый в сверкающие доспехи, остановился на перепутье, окруженный дремучим лесом, который полон таинственных шорохов и древних легенд.\n \
  Солнце, пробиваясь сквозь листву, играло золотыми лучами на его щите, на котором гордо красовался герб его дома. Взгляд его был устремлён в даль, к двум тропам, каждая из которых вела в неизвестность.\n \
  \n \
  Первая тропа, усыпанная яркими цветами, вилась к яркому свету, словно маня зовом приключений и радости.\n \
  Вторая же, каменистая и извивающаяся, поднималась к величественной горе, что возвышалась над всем вокруг, сулячи высоту славы, но вырисовывая опасности на своём пути.\n \
  \n \
  Рыцарь остановился, стараясь унять бурю мыслей в своём сердце. Каждый путь определял его судьбу, и решение требовало мужества.\n \
  Он знал, что, выбрав один из них, он обретёт не только новые знания и опыты, но и возможно, потеряет что-то ценное.\n \
  Сжав в руках рукоять меча, он сделал глубокий вдох, позволяя себе на мгновение прислушаться к звукам природы — шёпот ветра, пение птиц, тишину, полную ожидания.\n \
  \n \
  Собравшись с мыслями, рыцарь посмотрел на каждую из троп, обдумывая свои цели и идеалы.\n \
  Он знал, что каждый выбор — это шаг к судьбе, и его сердце подсказывало ему, что истинная сила заключается не в мечах и доспехах,\n \
  а в способности следовать зову своего сердца. В конце концов, он сделал шаг вперёд, выбирая тот путь, который был ему ближе всего.')
  print('-------\n \
        Куда же двигаться?\n \
        1. Направиться в город\n \
        2. Двигаться в логово дракона')
  answer = int(input())
  if answer == 1:
    print(f'---------------\n \
    Рыцарь {name}, чувствуя холодный стальной вес меча в руке, вздохнул и замер на месте.\n \
    Заглядывая в будущее, он задумался о последствиях своего выбора.\n \
    Мысли о славе и богатствах, которые могли бы ждать его в бою с драконом, начали меркнуть под давлением более разумных соображений.\n \
    \n \
    Он оглядел живописный город на одной из дорог и слышал веселые голоса людей, которые веселились на празднике.\n \
    Воспоминания о его родном доме и близких, которые уверяли его, что истинная доблесть заключается не только в сражениях,\n \
    но и в защите мира, наполнили его сердце теплом. "Почему бы не помочь тем, кто действительно нуждается?" — подумал {name}.\n \
    В конце концов, жителям города могла грозить опасность от разбойников, и защита их будет более благородным поступком, чем борьба с мифическим чудовищем.\n \
    \n \
    После секундной паузы, словно воодушевлённый внутренним голосом, он сделал шаг к дороге, ведущей в город.\n \
    С каждой минутой он чувствовал, как груз сомнений спадает с его плеч.\n \
    Возможность вернуть мир и спокойствие высоко ценились, и помочь тем, кто в этом нуждается — вот что действительно важно для рыцаря.\n \
    \n \
    {name} направился по тропе, побуждая себя думать о том, как его действия могут изменить жизни других.\n \
    Он будет бороться не с драконом, а с тьмой в сердцах тех, кто выбрал путь насилия.\n \
    Вперёд к свету, к людям, которые ждали настоящего героя.\n \
    \n \
    Пусть дорога будет долгой и трудной, но он знал, что этот выбор сделает его истинным рыцарем — не за славу, но за честь и добро.')
    return 1
  else:
    print(f'Ветер шумел в кронах деревьев, когда светило солнце, окрашивая лес в золотистые оттенки.\n \
    Рыцарь Альрик стоял на распутье, его доспехи отбрасывали блеск, словно световые мечи, когда он собирался принять решение,\n \
    которое определит его судьбу. Перед ним раскинулись три дороги: одна вела к живописному городу,\n \
    другая — в темный лес, о котором ходили зловещие мифы, а третья — к древним руинам, где по слухам, обитал страшный дракон.\n \
    \n \
    Сжав в руке холодный меч, Альрик задумался. Битва с драконом обещала ему славу и богатства, но цена могла быть слишком высокой.\n \
    Местные жители рассказывали, что чудовище уничтожило целые деревни и охотилось на тех, кто осмеливался приблизиться к его логову.\n \
    \n \
    "Неужели я готов рискнуть жизнью ради легенды?" — думал Альрик, глядя на сверкающий меч.\n \
    В его сердце загорался огонь мужества. Он знал, что настоящие рыцари не боятся испытаний.\n \
    Оглядев остальные дороги, он ощутил, что они будут лишь пыльными путями, ведущими к обыденности.\n \
    \n \
    Итак, все подумав, Альрик сделал шаг вперед, поворачивая в сторону горы, где скрывался дракон.\n \
    С каждым шагом воодушевление росло, и с ним разгорался новый, неизведанный путь.')
    return 2


character = Character('Аргенти')
dragon = Dragon
ch_hp = character.hp
dr_hp = dragon.hp
name = character.name
if beginning(name) == 2:
  fight(character, dragon)
  final_history(ch_hp, dr_hp)
# Out:
# ---------------
#    Рыцарь, облачённый в сверкающие доспехи, остановился на перепутье, окруженный дремучим лесом, который полон таинственных шорохов и древних легенд.
#    Солнце, пробиваясь сквозь листву, играло золотыми лучами на его щите, на котором гордо красовался герб его дома. Взгляд его был устремлён в даль, к двум тропам, каждая из которых вела в неизвестность.
#
#    Первая тропа, усыпанная яркими цветами, вилась к яркому свету, словно маня зовом приключений и радости.
#    Вторая же, каменистая и извивающаяся, поднималась к величественной горе, что возвышалась над всем вокруг, сулячи высоту славы, но вырисовывая опасности на своём пути.
#
#    Рыцарь остановился, стараясь унять бурю мыслей в своём сердце. Каждый путь определял его судьбу, и решение требовало мужества.
#    Он знал, что, выбрав один из них, он обретёт не только новые знания и опыты, но и возможно, потеряет что-то ценное.
# ...

# %% [markdown]
# # Дополнительное задание

# %% [markdown]
# Задача: Система управления библиотекой
#
# **Цель**
# Создайте простую систему управления библиотекой, которая позволит пользователям добавлять книги, брать книги, возвращать книги и просматривать список доступных книг.
#
# **Требования**
#
# 1. **Определение класса**:
#    – Создайте класс с именем «Book» со следующими атрибутами:
#      - `title`
#      - `автор`
#      - `isbn`
#      - `is_borrowed` (по умолчанию `False`)
#
# 2. **Класс библиотеки**:
#    - Создайте класс с именем Library, который управляет коллекцией книг.
#    - Класс должен иметь следующие методы:
#      - `__init__(self)`: инициализирует пустой список книг.
#      - `add_book(self, book: Book)`: добавляет новую книгу в библиотеку.
#      - `borrow_book(self, isbn: str)`: помечает книгу как заимствованную. Если книга не найдена или уже взята, выведите соответствующее сообщение.
#      - `return_book(self, isbn: str)`: помечает книгу как возвращенную. Если книга не найдена или не была взята взаймы, выведите соответствующее сообщение.
#      - `list_available_books(self)`: печатает список всех доступных книг в библиотеке.
#      - `find_book(self, isbn: str)`: возвращает объект книги, если он найден, в противном случае возвращает `None`.
#
# 3. **Взаимодействие с пользователем**:
#    - Создайте простое текстовое меню, которое позволит пользователям:
#      - Добавить книгу
#      - Одолжить книгу
#      - Вернуть книгу
#      - Список доступных книг
#      - Выйти из программы
